# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('Houses prices.csv')
df

# %%
df = pd.read_csv('Houses prices.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.price = df.price.round(2)
df.price
# Out:
# 0        313000.00
# 1       2384000.00
# 2        342000.00
# 3        420000.00
# 4        550000.00
#            ...
# 4595     308166.67
# 4596     534333.33
# 4597     416904.17
# 4598     203400.00
# 4599     220600.00
# Name: price, Length: 4600, dtype: float64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.describe(include= 'O')
# Out:
#                        date                 street     city  statezip country
# count                  4600                   4600     4600      4600    4600
# unique                   70                   4525       44        77       1
# top     2014-06-23 00:00:00  2520 Mulberry Walk NE  Seattle  WA 98103     USA
# freq                    142                      4     1573       148    4600

# %% [markdown]
# ### Data Cleaning

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.date
# Out:
# 0       2014-05-02 00:00:00
# 1       2014-05-02 00:00:00
# 2       2014-05-02 00:00:00
# 3       2014-05-02 00:00:00
# 4       2014-05-02 00:00:00
#                ...
# 4595    2014-07-09 00:00:00
# 4596    2014-07-09 00:00:00
# 4597    2014-07-09 00:00:00
# 4598    2014-07-10 00:00:00
# 4599    2014-07-10 00:00:00
# Name: date, Length: 4600, dtype: object

# %%
df.date = pd.to_datetime(df.date)
df.date
# Out:
# 0      2014-05-02
# 1      2014-05-02
# 2      2014-05-02
# 3      2014-05-02
# 4      2014-05-02
#           ...
# 4595   2014-07-09
# 4596   2014-07-09
# 4597   2014-07-09
# 4598   2014-07-10
# 4599   2014-07-10
# Name: date, Length: 4600, dtype: datetime64[ns]

# %%
df.date.describe()
# Out:
# count                             4600
# mean     2014-06-07 03:14:42.782608640
# min                2014-05-02 00:00:00
# 25%                2014-05-21 00:00:00
# 50%                2014-06-09 00:00:00
# 75%                2014-06-24 00:00:00
# max                2014-07-10 00:00:00
# Name: date, dtype: object

# %%
px.histogram(df, x= 'price')

# %%
px.box(df, x = 'price')

# %%
price_idx = df[df.price == 0].index
price_idx
# Out:
# Index([4354, 4356, 4357, 4358, 4361, 4362, 4374, 4376, 4382, 4383, 4385, 4386,
#        4389, 4394, 4405, 4408, 4411, 4412, 4413, 4420, 4442, 4448, 4453, 4454,
#        4472, 4478, 4479, 4480, 4481, 4487, 4499, 4507, 4509, 4520, 4521, 4522,
#        4523, 4528, 4534, 4542, 4552, 4554, 4555, 4558, 4563, 4567, 4574, 4575,
#        4588],
#       dtype='int64')

# %%
df.drop(price_idx, axis= 0, inplace= True)

df.reset_index(drop= True, inplace= True)
df
# Out:
#            date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02   313000.00       3.0       1.50         1340      7912
# 1    2014-05-02  2384000.00       5.0       2.50         3650      9050
# 2    2014-05-02   342000.00       3.0       2.00         1930     11947
# 3    2014-05-02   420000.00       3.0       2.25         2000      8030
# 4    2014-05-02   550000.00       4.0       2.50         1940     10500
# ...         ...         ...       ...        ...          ...       ...
# 4546 2014-07-09   308166.67       3.0       1.75         1510      6360
# 4547 2014-07-09   534333.33       3.0       2.50         1460      7573
# 4548 2014-07-09   416904.17       3.0       2.50         3010      7014
# 4549 2014-07-10   203400.00       4.0       2.00         2090      6630
# 4550 2014-07-10   220600.00       3.0       2.50         1490      8102
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
px.box(df, x = 'price')

# %%
round((df.bedrooms.value_counts() / df.shape[0]) * 100, 2)
# Out:
# bedrooms
# 3.0    44.50
# 4.0    33.22
# 2.0    12.33
# 5.0     7.43
# 6.0     1.30
# 1.0     0.81
# 7.0     0.31
# 8.0     0.04
# 0.0     0.04
# 9.0     0.02
# Name: count, dtype: float64

# %%
def bedrooms_func(x):

    if x in [6.0, 7.0, 8.0, 9.0]:
        return 6.0
    else:
        return x
    
df.bedrooms = df.bedrooms.apply(bedrooms_func)

# %%
df[df.bedrooms == 0]
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 2365 2014-06-12  1095000.0       0.0        0.0         3064      4764
# 3209 2014-06-24  1295648.0       0.0        0.0         4810     28008
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 2365     3.5           0     2          3        3064              0
# 3209     2.0           0     0          3        4810              0
#
#       yr_built  yr_renovated            street     city  statezip country
# 2365      1990          2009     814 E Howe St  Seattle  WA 98102     USA
# 3209      1990          2009  20418 NE 64th Pl  Redmond  WA 98053     USA

# %%
df.drop([2365, 3209], inplace= True)

df.reset_index(inplace= True, drop= True)

# %%
df.bedrooms.value_counts()
# Out:
# bedrooms
# 3.0    2025
# 4.0    1512
# 2.0     561
# 5.0     338
# 6.0      76
# 1.0      37
# Name: count, dtype: int64

# %%
round((df.bathrooms.value_counts() / df.shape[0]) * 100, 2)
# Out:
# bathrooms
# 2.50    26.03
# 1.00    16.18
# 1.75    13.81
# 2.00     9.34
# 2.25     9.08
# 1.50     6.31
# 2.75     5.94
# 3.00     3.61
# 3.50     3.50
# 3.25     2.97
# 3.75     0.75
# 4.50     0.57
# 4.25     0.48
# 4.00     0.46
# 0.75     0.37
# 4.75     0.15
# 5.00     0.11
# 5.25     0.09
# 5.50     0.09
# 1.25     0.07
# 8.00     0.02
# 5.75     0.02
# 6.50     0.02
# 6.25     0.02
# 6.75     0.02
# Name: count, dtype: float64

# %%
def bathrooms_func(x):

    if x in [0.75, 1, 1.25, 1.5, 1.75, 2]:
        return '0.75 - 2'
    elif x in [2.25, 2.5, 2.75, 3]:
        return '2.25 - 3'
    elif x in [3.25, 3.5, 3.75, 4]:
        return '3.25 - 4'
    else:
        return '4.25 - 8'
    
df.bathrooms = df.bathrooms.apply(bathrooms_func)

# %%
for col in ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']:

    df[col] = round(df[col] * 0.092903, 2)

df[['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']]
# Out:
#       sqft_living  sqft_lot  sqft_above  sqft_basement
# 0          124.49    735.05      124.49           0.00
# 1          339.10    840.77      313.08          26.01
# 2          179.30   1109.91      179.30           0.00
# 3          185.81    746.01       92.90          92.90
# 4          180.23    975.48      105.91          74.32
# ...           ...       ...         ...            ...
# 4544       140.28    590.86      140.28           0.00
# 4545       135.64    703.55      135.64           0.00
# 4546       279.64    651.62      279.64           0.00
# 4547       194.17    615.95       99.41          94.76
# 4548       138.43    752.70      138.43           0.00
#
# [4549 rows x 4 columns]

# %%
for col in ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']:

    fig = px.histogram(df, x= col)
    fig.show()

# %%
df[df.sqft_lot > 20000]
# Out:
#            date       price  bedrooms bathrooms  sqft_living  sqft_lot  \
# 122  2014-05-05  2280000.00       6.0  4.25 - 8      1257.91  28591.08
# 240  2014-05-07   630000.00       3.0  2.25 - 3       248.98  30391.82
# 272  2014-05-07   900000.00       5.0  3.25 - 4       383.69  21003.14
# 375  2014-05-08   330000.00       2.0  0.75 - 2       144.00  40468.55
# 479  2014-05-12   560000.00       3.0  0.75 - 2       237.83  20139.23
# 484  2014-05-12   540000.00       4.0  2.25 - 3       235.97  21205.48
# 495  2014-05-12   950000.00       5.0  2.25 - 3       420.85  24038.28
# 679  2014-05-14   543000.00       2.0  0.75 - 2       220.18  20234.27
# 747  2014-05-15   350000.00       3.0  0.75 - 2       156.08  23269.41
# 879  2014-05-19   480000.00       4.0  3.25 - 4       313.08  40468.55
# 1031 2014-05-20   439000.00       3.0  0.75 - 2       186.74  23350.33
# 1078 2014-05-21   542500.00       5.0  3.25 - 4       279.64  99798.07
# ...

# %%
df.floors.value_counts()
# Out:
# floors
# 1.0    2151
# 2.0    1790
# 1.5     439
# 3.0     127
# 2.5      41
# 3.5       1
# Name: count, dtype: int64

# %%
def floors_func(x):

    if x in [1, 1.5]:
        return '1 - 1.5'
    elif x in [2, 2.5]:
        return '2 - 2.5'
    else:
        return '3 - 3.5'
    
df.floors = df.floors.apply(floors_func)

# %%
df.waterfront.value_counts()
# Out:
# waterfront
# 0    4519
# 1      30
# Name: count, dtype: int64

# %%
df.view.value_counts()
# Out:
# view
# 0    4102
# 2     200
# 3     115
# 1      69
# 4      63
# Name: count, dtype: int64

# %%
df.condition.value_counts()
# Out:
# condition
# 3    2849
# 4    1238
# 5     425
# 2      31
# 1       6
# Name: count, dtype: int64

# %%
def condition_func(x):

    if x in [1, 2]:
        return 2
    else:
        return x
    
df.condition = df.condition.apply(condition_func)

# %%
px.histogram(df, x= 'yr_built')

# %%
px.histogram(df, x= 'yr_renovated')

# %%
df.yr_renovated.unique()
# Out:
# array([2005,    0, 1992, 1994, 2010, 1988, 2009, 1969, 2000, 1979, 1989,
#        2014, 1999, 2003, 1983, 1997, 1912, 1923, 1954, 2011, 2001, 2013,
#        2006, 1972, 1985, 1998, 2004, 1958, 2008, 1970, 1982, 1986, 1996,
#        2002, 1971, 1990, 1956, 1945, 1984, 2012, 1993, 2007, 1981, 1974,
#        1963, 1968, 1995, 1934, 1953, 1966, 1955, 1987, 1960, 1978, 1980,
#        1948, 1991, 1913, 1977], dtype=int64)

# %%
df.drop('street', inplace= True, axis= 1)
df.duplicated().sum()
# Out:
# 0

# %%
df.city.value_counts() / df.shape[0] * 100
# Out:
# city
# Seattle                34.293251
# Renton                  6.397010
# Bellevue                6.177182
# Redmond                 5.143988
# Kirkland                4.110794
# Issaquah                4.088811
# Kent                    4.044845
# Auburn                  3.846999
# Sammamish               3.759068
# Federal Way             3.187514
# Shoreline               2.703891
# Woodinville             2.506045
# Maple Valley            2.088371
# Mercer Island           1.802594
# Burien                  1.582765
# Snoqualmie              1.516817
# Kenmore                 1.428885
# Des Moines              1.275005
# North Bend              1.099143
# Duvall                  0.923280
# Covington               0.923280
# Lake Forest Park        0.747417
# Bothell                 0.725434
# Newcastle               0.725434
# Tukwila                 0.637503
# Vashon                  0.637503
# SeaTac                  0.615520
# Enumclaw                0.593537
# ...

# %%
df.city.value_counts()
# Out:
# city
# Seattle                1560
# Renton                  291
# Bellevue                281
# Redmond                 234
# Kirkland                187
# Issaquah                186
# Kent                    184
# Auburn                  175
# Sammamish               171
# Federal Way             145
# Shoreline               123
# Woodinville             114
# Maple Valley             95
# Mercer Island            82
# Burien                   72
# Snoqualmie               69
# Kenmore                  65
# Des Moines               58
# North Bend               50
# Duvall                   42
# Covington                42
# Lake Forest Park         34
# Bothell                  33
# Newcastle                33
# Tukwila                  29
# Vashon                   29
# SeaTac                   28
# Enumclaw                 27
# Carnation                22
# Normandy Park            17
# Fall City                11
# Medina                   11
# Clyde Hill                9
# ...

# %%
df.city.value_counts()
# Out:
# city
# Seattle                1560
# Renton                  291
# Bellevue                281
# Redmond                 234
# Kirkland                187
# Issaquah                186
# Kent                    184
# Auburn                  175
# Sammamish               171
# Federal Way             145
# Shoreline               123
# Woodinville             114
# Maple Valley             95
# Mercer Island            82
# Burien                   72
# Snoqualmie               69
# Kenmore                  65
# Des Moines               58
# North Bend               50
# Duvall                   42
# Covington                42
# Lake Forest Park         34
# Bothell                  33
# Newcastle                33
# Tukwila                  29
# Vashon                   29
# SeaTac                   28
# Enumclaw                 27
# Carnation                22
# Normandy Park            17
# Fall City                11
# Medina                   11
# Clyde Hill                9
# ...

# %%
others_cities = df['city'].value_counts(normalize=True)[df['city'].value_counts(normalize=True) < 0.01].index.values
others_cities
# Out:
# array(['Duvall', 'Covington', 'Lake Forest Park', 'Bothell', 'Newcastle',
#        'Tukwila', 'Vashon', 'SeaTac', 'Enumclaw', 'Carnation',
#        'Normandy Park', 'Fall City', 'Medina', 'Clyde Hill',
#        'Black Diamond', 'Ravensdale', 'Pacific', 'Algona', 'Yarrow Point',
#        'Skykomish', 'Preston', 'Milton', 'Inglewood-Finn Hill',
#        'Snoqualmie Pass', 'Beaux Arts Village'], dtype=object)

# %%
def city_func(x):

    if x in others_cities:
        return 'Other'
    else:
        return x
    
df.city = df.city.apply(city_func)
df.city.value_counts()
# Out:
# city
# Seattle          1560
# Other             407
# Renton            291
# Bellevue          281
# Redmond           234
# Kirkland          187
# Issaquah          186
# Kent              184
# Auburn            175
# Sammamish         171
# Federal Way       145
# Shoreline         123
# Woodinville       114
# Maple Valley       95
# Mercer Island      82
# Burien             72
# Snoqualmie         69
# Kenmore            65
# Des Moines         58
# North Bend         50
# Name: count, dtype: int64

# %%
df.drop(['statezip', 'country'], axis= 1, inplace= True)

df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'city'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering

# %%
df.date
# Out:
# 0      2014-05-02
# 1      2014-05-02
# 2      2014-05-02
# 3      2014-05-02
# 4      2014-05-02
#           ...
# 4544   2014-07-09
# 4545   2014-07-09
# 4546   2014-07-09
# 4547   2014-07-10
# 4548   2014-07-10
# Name: date, Length: 4549, dtype: datetime64[ns]

# %%
df['month'] = df.date.dt.month_name()
df['month']
# Out:
# 0        May
# 1        May
# 2        May
# 3        May
# 4        May
#         ...
# 4544    July
# 4545    July
# 4546    July
# 4547    July
# 4548    July
# Name: month, Length: 4549, dtype: object

# %%
df['day'] = df.date.dt.day
df['day']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 4544     9
# 4545     9
# 4546     9
# 4547    10
# 4548    10
# Name: day, Length: 4549, dtype: int32

# %%
df
# Out:
#            date       price  bedrooms bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02   313000.00       3.0  0.75 - 2       124.49    735.05
# 1    2014-05-02  2384000.00       5.0  2.25 - 3       339.10    840.77
# 2    2014-05-02   342000.00       3.0  0.75 - 2       179.30   1109.91
# 3    2014-05-02   420000.00       3.0  2.25 - 3       185.81    746.01
# 4    2014-05-02   550000.00       4.0  2.25 - 3       180.23    975.48
# ...         ...         ...       ...       ...          ...       ...
# 4544 2014-07-09   308166.67       3.0  0.75 - 2       140.28    590.86
# 4545 2014-07-09   534333.33       3.0  2.25 - 3       135.64    703.55
# 4546 2014-07-09   416904.17       3.0  2.25 - 3       279.64    651.62
# 4547 2014-07-10   203400.00       4.0  0.75 - 2       194.17    615.95
# 4548 2014-07-10   220600.00       3.0  2.25 - 3       138.43    752.70
#
#        floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
df.waterfront.value_counts()
# Out:
# waterfront
# 0    4519
# 1      30
# Name: count, dtype: int64

# %%
df.city.nunique()
# Out:
# 20

# %%
df.month.nunique()
# Out:
# 3

# %%
# Drop Unneccessary columns before preprocessing

df.drop(['date'], axis= 1, inplace= True)

df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#            price  bedrooms bathrooms  sqft_living  sqft_lot   floors  \
# 0      313000.00       3.0  0.75 - 2       124.49    735.05  1 - 1.5
# 1     2384000.00       5.0  2.25 - 3       339.10    840.77  2 - 2.5
# 2      342000.00       3.0  0.75 - 2       179.30   1109.91  1 - 1.5
# 3      420000.00       3.0  2.25 - 3       185.81    746.01  1 - 1.5
# 4      550000.00       4.0  2.25 - 3       180.23    975.48  1 - 1.5
# ...          ...       ...       ...          ...       ...      ...
# 4544   308166.67       3.0  0.75 - 2       140.28    590.86  1 - 1.5
# 4545   534333.33       3.0  2.25 - 3       135.64    703.55  2 - 2.5
# 4546   416904.17       3.0  2.25 - 3       279.64    651.62  2 - 2.5
# 4547   203400.00       4.0  0.75 - 2       194.17    615.95  1 - 1.5
# 4548   220600.00       3.0  2.25 - 3       138.43    752.70  2 - 2.5
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
# Split data into inpute features and target variable

x = df.drop('price', axis= 1)
y = df['price']

# %%
# split into train and test
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 42)
x_train
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot   floors  waterfront  view  \
# 540        3.0  2.25 - 3       145.86    133.13  3 - 3.5           0     0
# 3949       3.0  0.75 - 2       229.47    817.55  2 - 2.5           0     0
# 2098       3.0  2.25 - 3       205.32    743.22  2 - 2.5           0     0
# 3389       3.0  2.25 - 3       167.23    259.20  2 - 2.5           0     0
# 3386       4.0  2.25 - 3       192.31    503.07  2 - 2.5           0     0
# ...        ...       ...          ...       ...      ...         ...   ...
# 4426       4.0  0.75 - 2       239.69    557.42  1 - 1.5           0     0
# 466        4.0  0.75 - 2       234.12    557.42  1 - 1.5           0     0
# 3092       2.0  0.75 - 2        80.83   1031.22  1 - 1.5           0     0
# 3772       4.0  2.25 - 3       197.88    587.61  1 - 1.5           0     0
# 860        2.0  0.75 - 2       138.43    355.35  1 - 1.5           0     0
#
# ...

# %% [markdown]
# ### Feature scaling

# %%
scaled_cols = ['bedrooms', 'sqft_lot', 'yr_built', 'yr_renovated', 'day','sqft_living', 'sqft_above', 'sqft_basement']

from sklearn.preprocessing import RobustScaler

rc = RobustScaler()
x_train[scaled_cols] = rc.fit_transform(x_train[scaled_cols])
x_test[scaled_cols] = rc.transform(x_test[scaled_cols])

# %%
x_train
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot   floors  waterfront  view  \
# 540        0.0  2.25 - 3    -0.350864 -1.056154  3 - 3.5           0     0
# 3949       0.0  0.75 - 2     0.438580  0.199213  2 - 2.5           0     0
# 2098       0.0  2.25 - 3     0.210556  0.062877  2 - 2.5           0     0
# 3389       0.0  2.25 - 3    -0.149089 -0.824916  2 - 2.5           0     0
# 3386       1.0  2.25 - 3     0.087716 -0.377608  2 - 2.5           0     0
# ...        ...       ...          ...       ...      ...         ...   ...
# 4426       1.0  0.75 - 2     0.535077 -0.277919  1 - 1.5           0     0
# 466        1.0  0.75 - 2     0.482485 -0.277919  1 - 1.5           0     0
# 3092      -1.0  0.75 - 2    -0.964876  0.591128  1 - 1.5           0     0
# 3772       1.0  2.25 - 3     0.140308 -0.222544  1 - 1.5           0     0
# 860       -1.0  0.75 - 2    -0.421018 -0.648557  1 - 1.5           0     0
#
# ...

# %% [markdown]
# ### Handling Categorical Features (Nominal)

# %%
x_train
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot   floors  waterfront  view  \
# 540        0.0  2.25 - 3    -0.350864 -1.056154  3 - 3.5           0     0
# 3949       0.0  0.75 - 2     0.438580  0.199213  2 - 2.5           0     0
# 2098       0.0  2.25 - 3     0.210556  0.062877  2 - 2.5           0     0
# 3389       0.0  2.25 - 3    -0.149089 -0.824916  2 - 2.5           0     0
# 3386       1.0  2.25 - 3     0.087716 -0.377608  2 - 2.5           0     0
# ...        ...       ...          ...       ...      ...         ...   ...
# 4426       1.0  0.75 - 2     0.535077 -0.277919  1 - 1.5           0     0
# 466        1.0  0.75 - 2     0.482485 -0.277919  1 - 1.5           0     0
# 3092      -1.0  0.75 - 2    -0.964876  0.591128  1 - 1.5           0     0
# 3772       1.0  2.25 - 3     0.140308 -0.222544  1 - 1.5           0     0
# 860       -1.0  0.75 - 2    -0.421018 -0.648557  1 - 1.5           0     0
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop= 'first', sparse_output= False)

x_train['month'] = ohe.fit_transform(x_train[['month']])
x_test['month'] = ohe.transform(x_test[['month']])

# %%
x_train.month
# Out:
# 540     0.0
# 3949    0.0
# 2098    1.0
# 3389    1.0
# 3386    1.0
#        ...
# 4426    1.0
# 466     0.0
# 3092    1.0
# 3772    0.0
# 860     0.0
# Name: month, Length: 3639, dtype: float64

# %%
# Features with high categories, handle by Binary encoder
from category_encoders import BinaryEncoder
BE = BinaryEncoder()

x_train_BE = BE.fit_transform(x_train[['city']])
x_test_BE = BE.transform(x_test[['city']])

# %%
x_train_BE
# Out:
#       city_0  city_1  city_2  city_3  city_4
# 540        0       0       0       0       1
# 3949       0       0       0       1       0
# 2098       0       0       0       1       1
# 3389       0       0       0       0       1
# 3386       0       0       1       0       0
# ...      ...     ...     ...     ...     ...
# 4426       0       0       0       0       1
# 466        0       0       0       0       1
# 3092       0       0       0       0       1
# 3772       0       0       0       0       1
# 860        0       0       0       0       1
#
# [3639 rows x 5 columns]

# %%
x_train.drop('city', axis= 1, inplace= True)
x_test.drop('city', axis= 1, inplace= True)

# %%
x_train = pd.concat([x_train, x_train_BE], axis= 1)
x_test = pd.concat([x_test, x_test_BE], axis= 1)

# %%
x_train
# Out:
#       bedrooms bathrooms  sqft_living  sqft_lot   floors  waterfront  view  \
# 540        0.0  2.25 - 3    -0.350864 -1.056154  3 - 3.5           0     0
# 3949       0.0  0.75 - 2     0.438580  0.199213  2 - 2.5           0     0
# 2098       0.0  2.25 - 3     0.210556  0.062877  2 - 2.5           0     0
# 3389       0.0  2.25 - 3    -0.149089 -0.824916  2 - 2.5           0     0
# 3386       1.0  2.25 - 3     0.087716 -0.377608  2 - 2.5           0     0
# ...        ...       ...          ...       ...      ...         ...   ...
# 4426       1.0  0.75 - 2     0.535077 -0.277919  1 - 1.5           0     0
# 466        1.0  0.75 - 2     0.482485 -0.277919  1 - 1.5           0     0
# 3092      -1.0  0.75 - 2    -0.964876  0.591128  1 - 1.5           0     0
# 3772       1.0  2.25 - 3     0.140308 -0.222544  1 - 1.5           0     0
# 860       -1.0  0.75 - 2    -0.421018 -0.648557  1 - 1.5           0     0
#
# ...

# %% [markdown]
# ### Handling Categorical Features (ordinal)

# %%
x_train.bathrooms.value_counts()
# Out:
# bathrooms
# 0.75 - 2    1683
# 2.25 - 3    1619
# 3.25 - 4     287
# 4.25 - 8      50
# Name: count, dtype: int64

# %%
# Arrange each category as per importance
bathrooms_map = {'0.75 - 2' : 1,
                 '2.25 - 3' : 2,
                 '3.25 - 4' : 3,
                 '4.25 - 8' : 4}

x_train.bathrooms = x_train.bathrooms.map(bathrooms_map)
x_test.bathrooms = x_test.bathrooms.map(bathrooms_map)

# %%
x_train.bathrooms
# Out:
# 540     2
# 3949    1
# 2098    2
# 3389    2
# 3386    2
#        ..
# 4426    1
# 466     1
# 3092    1
# 3772    2
# 860     1
# Name: bathrooms, Length: 3639, dtype: int64

# %%
x_train.floors.value_counts()
# Out:
# floors
# 1 - 1.5    2074
# 2 - 2.5    1463
# 3 - 3.5     102
# Name: count, dtype: int64

# %%
# Arrange each category as per importance
floors_map = {'1 - 1.5' : 1,
                 '2 - 2.5' : 2,
                 '3 - 3.5' : 3
                 }

x_train.floors = x_train.floors.map(floors_map)
x_test.floors = x_test.floors.map(floors_map)

# %%
x_train.floors
# Out:
# 540     3
# 3949    2
# 2098    2
# 3389    2
# 3386    2
#        ..
# 4426    1
# 466     1
# 3092    1
# 3772    1
# 860     1
# Name: floors, Length: 3639, dtype: int64

# %%
x_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 540        0.0          2    -0.350864 -1.056154       3           0     0
# 3949       0.0          1     0.438580  0.199213       2           0     0
# 2098       0.0          2     0.210556  0.062877       2           0     0
# 3389       0.0          2    -0.149089 -0.824916       2           0     0
# 3386       1.0          2     0.087716 -0.377608       2           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4426       1.0          1     0.535077 -0.277919       1           0     0
# 466        1.0          1     0.482485 -0.277919       1           0     0
# 3092      -1.0          1    -0.964876  0.591128       1           0     0
# 3772       1.0          2     0.140308 -0.222544       1           0     0
# 860       -1.0          1    -0.421018 -0.648557       1           0     0
#
# ...

# %% [markdown]
# ### Machine Learning

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

le = LinearRegression()

le.fit(x_train, np.log(y_train))

print('Training score : ', round(le.score(x_train, np.log(y_train)) * 100, 2), '%')
print('Test score : ', round(le.score(x_test, np.log(y_test)) * 100, 2), '%')
# Out:
# Training score :  58.75 %
# Test score :  57.14 %

# %%
la = Lasso(0.0001)

la.fit(x_train, np.log(y_train))
print('Training score : ', round(la.score(x_train, np.log(y_train)) * 100, 2), '%')
print('Test score : ', round(la.score(x_test, np.log(y_test)) * 100, 2), '%')
# Out:
# Training score :  58.75 %
# Test score :  57.11 %
# c:\Users\hp\.conda\envs\DS\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.873e-01, tolerance: 1.061e-01

# %%
rd = Ridge()

rd.fit(x_train, np.log(y_train))
print('Training score : ', round(rd.score(x_train, np.log(y_train)) * 100, 2), '%')
print('Test score : ', round(rd.score(x_test, np.log(y_test)) * 100, 2), '%')
# Out:
# Training score :  58.75 %
# Test score :  57.12 %

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree= 2)

x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)
le.fit(x_train_poly, np.log(y_train))

print('Training score : ', round(le.score(x_train_poly, np.log(y_train)) * 100, 2), '%')
print('Test score : ', round(le.score(x_test_poly, np.log(y_test)) * 100, 2), '%')
# Out:
# Training score :  69.49 %
# Test score :  54.62 %

# %% [markdown]
# ### Notes
# - Results shows that model underfits the data, so we need to increase more features in the model and try to remove more noise from the data or use more complex models as we will see soon
